# %% [markdown]
# # Library Import

# %%
import pandas as pd 
import yfinance as yf
import polygon 
import numpy as np
from dotenv import load_dotenv
import os
import requests

# %% [markdown]
# ## Yahoo Finance

# %% [markdown]
# ### YF Raw Data Loading

# %%
from curl_cffi import requests
session = requests.Session(impersonate="chrome")
ticker = yf.Ticker('AAPL', session=session)
ticker.history(period='max')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.098485    0.098913    0.098485    0.098485
# 1980-12-15 00:00:00-05:00    0.093775    0.093775    0.093347    0.093347
# 1980-12-16 00:00:00-05:00    0.086924    0.086924    0.086495    0.086495
# 1980-12-17 00:00:00-05:00    0.088636    0.089064    0.088636    0.088636
# 1980-12-18 00:00:00-05:00    0.091206    0.091634    0.091206    0.091206
# ...                               ...         ...         ...         ...
# 2025-09-08 00:00:00-04:00  239.300003  240.149994  236.339996  237.880005
# 2025-09-09 00:00:00-04:00  237.000000  238.779999  233.360001  234.350006
# 2025-09-10 00:00:00-04:00  232.190002  232.419998  225.949997  226.789993
# 2025-09-11 00:00:00-04:00  226.880005  230.449997  226.649994  230.029999
# 2025-09-12 00:00:00-04:00  229.220001  234.509995  229.020004  234.070007
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# Download Data
yf.download(['ADS1.DU'], period='max')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ADS1.DU']: AttributeError("'str' object has no attribute 'name'")
# YF.download() has changed argument auto_adjust default to True
# Empty DataFrame
# Columns: [(Adj Close, ADS1.DU), (Close, ADS1.DU), (High, ADS1.DU), (Low, ADS1.DU), (Open, ADS1.DU), (Volume, ADS1.DU)]
# Index: []

# %% [markdown]
# ### YF Bulk Raw Data Loading

# %%
# Yahoo Finance Batch Download
yf.download(['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'TSLA', 'NVDA', 'JPM', 'V', 'WMT', 
            'BAC', 'JNJ', 'PG', 'MA', 'HD', 'DIS', 'PFE', 'KO', 'NFLX', 'CSCO', 
            'ABBV', 'PEP', 'T', 'MRK', 'INTC', 'CVX', 'MCD', 'WFC', 'ABT', 'VZ', 
            'TMO', 'CRM', 'BMY', 'UNH', 'LOW', 'NKE', 'HON', 'ORCL', 'ACN', 'DHR', 
            'LIN', 'PM', 'UPS', 'RTX', 'AMD', 'IBM', 'QCOM', 'TXN', 'INTU', 'ADP'], period='max')
# Out:
# [*********************100%***********************]  50 of 50 completed
#
# 50 Failed downloads:
# ['MA', 'V', 'TXN', 'ADP', 'TMO', 'T', 'AMD', 'AMZN', 'KO', 'VZ', 'NKE', 'DHR', 'JNJ', 'PG', 'RTX', 'CVX', 'WFC', 'MRK', 'MCD', 'INTC', 'INTU', 'UNH', 'NFLX', 'MSFT', 'WMT', 'HON', 'ACN', 'PM', 'LIN', 'CSCO', 'AAPL', 'BAC', 'CRM', 'QCOM', 'TSLA', 'PFE', 'UPS', 'LOW', 'ABBV', 'GOOGL', 'BMY', 'JPM', 'META', 'ORCL', 'IBM', 'PEP', 'ABT', 'NVDA', 'DIS', 'HD']: AttributeError("'str' object has no attribute 'name'")
# Empty DataFrame
# ...

# %% [markdown]
# ### YF Asyn Loading Test

# %%
import asyncio
import time
from concurrent.futures import ThreadPoolExecutor

def test_concurrent_requests():
    
    max_workers = 50  # Test with different numbers
    symbols = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'META', 'TSLA', 'NVDA', 'JPM', 'V', 'WMT', 
            'BAC', 'JNJ', 'PG', 'MA', 'HD', 'DIS', 'PFE', 'KO', 'NFLX', 'CSCO', 
            'ABBV', 'PEP', 'T', 'MRK', 'INTC', 'CVX', 'MCD', 'WFC', 'ABT', 'VZ', 
            'TMO', 'CRM', 'BMY', 'UNH', 'LOW', 'NKE', 'HON', 'ORCL', 'ACN', 'DHR', 
            'LIN', 'PM', 'UPS', 'RTX', 'AMD', 'IBM', 'QCOM', 'TXN', 'INTU', 'ADP']
    
    def fetch_data(symbol):
        try:
            start_time = time.time()
            ticker = yf.Ticker(symbol)
            data = ticker.history(period='max')
            end_time = time.time()
            return {
                'symbol': symbol,
                'success': True,
                'time_taken': end_time - start_time,
                'data_points': len(data)
            }
        except Exception as e:
            return {
                'symbol': symbol,
                'success': False,
                'error': str(e)
            }
    
    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(fetch_data, symbol) for symbol in symbols]
        for future in futures:
            results.append(future.result())
    
    # Print results
    print(f"\nTesting with {max_workers} concurrent workers:")
    print("=" * 50)
    for result in results:
        if result['success']:
            print(f"{result['symbol']}: Success - {result['time_taken']:.2f}s - {result['data_points']} data points")
        else:
            print(f"{result['symbol']}: Failed - {result['error']}")

# Run the test
test_concurrent_requests()
# Out:
# Testing with 50 concurrent workers:
# ...
# AAPL: Success - 0.55s - 11188 data points
# MSFT: Success - 1.39s - 9862 data points
# GOOGL: Success - 0.68s - 5210 data points
# AMZN: Success - 0.75s - 7036 data points
# META: Success - 0.38s - 3258 data points
# TSLA: Success - 0.70s - 3735 data points
# NVDA: Success - 1.02s - 6611 data points
# JPM: Success - 1.88s - 11376 data points
# V: Success - 0.44s - 4309 data points
# WMT: Success - 2.05s - 13282 data points
# BAC: Success - 1.92s - 13162 data points
# JNJ: Success - 2.10s - 15941 data points
# PG: Success - 2.46s - 15941 data points
# MA: Success - 0.56s - 4765 data points
# HD: Success - 1.77s - 10993 data points
# DIS: Success - 2.66s - 15941 data points
# PFE: Success - 2.35s - 13342 data points
# KO: Success - 2.47s - 15941 data points
# NFLX: Success - 0.74s - 5774 data points
# CSCO: Success - 1.02s - 8867 data points
# ABBV: Success - 0.42s - 3103 data points
# PEP: Success - 1.82s - 13342 data points
# ...

# %% [markdown]
# ## Polygon API

# %% [markdown]
# ### Raw Data Loading

# %%
# Load environment variables
load_dotenv()

# Fetch OHLCV data
# Get Polygon API key
api_key = os.environ.get('POLYGON_API_KEY')
if not api_key:
    raise ValueError("POLYGON_API_KEY environment variable not found")

# API parameters
params = {
    'ticker': 'AGM.A',
    'multiplier': 1,
    'timespan': 'day',
    'adjusted': False,
    'sort': 'asc',
    'apiKey': api_key,
    'from': '2023-01-01',  # Add date range
    'to': '2023-12-31'
}

# Make API request
url = "https://api.polygon.io/v2/aggs/grouped/locale/us/market/stocks/2023-01-01"
response = requests.get(url, params=params)

# Check response status
if response.status_code != 200:
    raise Exception(f"API request failed with status code {response.status_code}")

try:
    response_json = response.json()
except requests.exceptions.JSONDecodeError as e:
    raise Exception(f"Failed to decode JSON response: {str(e)}")

# %%
from polygon import RESTClient
# Load environment variables
load_dotenv()

# Fetch OHLCV data
# Get Polygon API key
api_key = os.environ.get('POLYGON_API_KEY')
if not api_key:
    raise ValueError("POLYGON_API_KEY environment variable not found")

# API parameters
params = {
    'ticker': 'AGM.A',
    'apiKey': api_key,
}

# Make API request
url = "https://api.polygon.io/v3/reference/tickers/"
response = requests.get(url, params=params)

# Check response status
if response.status_code != 200:
    raise Exception(f"API request failed with status code {response.status_code}")

try:
    response_json = response.json()
except requests.exceptions.JSONDecodeError as e:
    raise Exception(f"Failed to decode JSON response: {str(e)}")

# %%
response_json['results'][0]
# Out:
# {'ticker': 'AGM.A',
#  'name': 'Federal Agricultural Mortgage Corporation Class A Voting',
#  'market': 'stocks',
#  'locale': 'us',
#  'primary_exchange': 'XNYS',
#  'type': 'CS',
#  'active': True,
#  'currency_name': 'usd',
#  'cik': '0000845877',
#  'composite_figi': 'BBG000G8Y1Z6',
#  'share_class_figi': 'BBG001SCWN95',
#  'last_updated_utc': '2025-05-09T00:00:00Z'}

# %% [markdown]
# ### Fetch Active Conmmon Stock

# %%
# Get all active tickers
tickers_response = RESTClient(api_key=api_key).list_tickers( market="stocks", active=True, limit=1000)

ticker_list = []
# Filter and extract only common stocks (CS) and exchange in XNYS, XNAS, XAMS 
ticker_list.extend([{
    'symbol': ticker.ticker,
    'name': ticker.name,
    'market': ticker.market,
    'type': ticker.type,
    'active': ticker.active,
    'primary_exchange': ticker.primary_exchange,
    'currency_name': ticker.currency_name,
} for ticker in tickers_response if ticker.type in ['CS', 'ADRC'] and ticker.primary_exchange in ['XNYS', 'XNAS', 'XAMS']])

ticker_list
# Out:
# [{'symbol': 'A',
#   'name': 'Agilent Technologies Inc.',
#   'market': 'stocks',
#   'type': 'CS',
#   'active': True,
#   'primary_exchange': 'XNYS',
#   'currency_name': 'usd'},
#  {'symbol': 'AA',
#   'name': 'Alcoa Corporation',
#   'market': 'stocks',
#   'type': 'CS',
#   'active': True,
#   'primary_exchange': 'XNYS',
#   'currency_name': 'usd'},
#  {'symbol': 'AACB',
#   'name': 'Artius II Acquisition Inc. Class A Ordinary Shares',
#   'market': 'stocks',
#   'type': 'CS',
#   'active': True,
#   'primary_exchange': 'XNAS',
#   'currency_name': 'usd'},
#  {'symbol': 'AACG',
#   'name': 'ATA Creativity Global American Depositary Shares',
#   'market': 'stocks',
#   'type': 'ADRC',
#   'active': True,
#   'primary_exchange': 'XNAS',
#   'currency_name': 'usd'},
#  {'symbol': 'AACT',
#   'name': 'Ares Acquisition Corporation II',
#   'market': 'stocks',
#   'type': 'CS',
#   'active': True,
#   'primary_exchange': 'XNYS',
#   'currency_name': 'usd'},
#  {'symbol': 'AAL',
# ...

# %% [markdown]
# ### Get Market Status

# %%
# Fetch the market status of NASDAQ
RESTClient(api_key=api_key).get_market_status().exchanges.nasdaq

# Fetch the market server time
RESTClient(api_key=api_key).get_market_status().server_time
# Out:
# '2025-05-11T13:23:51-04:00'

# %% [markdown]
# ## Market Calender

# %%
import pandas_market_calendars as mcal
import pytz
from datetime import datetime
# Get NYSE calendar
nyse = mcal.get_calendar('NYSE')

# Get current NY time
ny_tz = pytz.timezone('America/New_York')
today = datetime.strptime('2025-05-02', '%Y-%m-%d')
end_date = datetime.strptime('2025-05-05', '%Y-%m-%d')
# Get market schedule
schedule = nyse.schedule(start_date=today, end_date=end_date)

print(len(schedule))

# Check if current time is past market close
current_time = datetime.now(pytz.timezone('America/New_York'))
last_market_close = schedule.iloc[-1]['market_close'].tz_convert('America/New_York') 

# Get market hours
market_open = schedule.iloc[0]['market_open'].tz_convert('America/New_York')
market_close = schedule.iloc[0]['market_close'].tz_convert('America/New_York')
    
trading_hours = pd.date_range(
    start=market_open,
    end=market_close,
    freq='1d',
    tz='America/New_York'
)[1:].tolist()
# Out:
# 2

# %%
# Check if market is closed
today = datetime.strptime('2025-05-11', '%Y-%m-%d')
end_date = datetime.strptime('2025-05-11', '%Y-%m-%d')
schedule = nyse.schedule(start_date=today, end_date=end_date)
schedule

print(schedule.empty)
# Out:
# True

# %% [markdown]
# ## Work Directory Examine

# %%
import pandas as pd 
import os 
import os

# Get the current working directory
current_path = os.getcwd()
print(f"Current working directory: {current_path}")

# List all directories in the current path
print("\nDirectories in current path:")
for item in os.listdir(current_path):
    if os.path.isdir(os.path.join(current_path, item)):
        print(f"- {item}")

# List all files in the current path
print("\nFiles in current path:")
for item in os.listdir(current_path):
    if os.path.isfile(os.path.join(current_path, item)):
        print(f"- {item}")

os.chdir("..")
# Out:
# Current working directory: /Users/yiukitcheung/Documents/Projects/condvest/data_pipeline/jupyter_notebook
#
# Directories in current path:
#
# Files in current path:
# - data_fetching.ipynb
# - olap.ipynb

# %%
# Get the current working directory
current_path = os.getcwd()
print(f"Current working directory: {current_path}")
# Out:
# Current working directory: /Users/yiukitcheung/Documents/Projects/condvest/data_pipeline
